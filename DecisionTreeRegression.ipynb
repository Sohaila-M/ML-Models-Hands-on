# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor, export_text
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("Position_Salaries.csv")

# %%
X = df[["Level"]]
y = df["Salary"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3.0, random_state=42)

# %%
regressor = DecisionTreeRegressor(random_state=42)
regressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
y_pred = regressor.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse:.4f}")
# Out:
# Mean Squared Error: 10481250000.0000

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(16, 10))

plot_tree(regressor, filled=True, feature_names=["Level"], rounded=True)

plt.title("Decision Tree Regression Visualization")
plt.show()
